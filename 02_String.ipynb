# %%
name = "rhushi"
name
# Out:
# 'rhushi'

# %%
name.upper()
# Out:
# 'RHUSHI'

# %%
name.endswith("shi")
# Out:
# True

# %%
name.endswith("shii")
# Out:
# False

# %%
name.lower()
# Out:
# 'rhushi'

# %%
name.count("r")
# Out:
# 1

# %%
print(len(name))
# Out:
# 6

# %%
name[0:4]
# Out:
# 'rhus'
