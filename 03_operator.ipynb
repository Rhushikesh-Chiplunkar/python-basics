# %%
a=3
b=2
a+b
# Out:
# 5

# %%
a>b
# Out:
# True

# %%
a**b
# Out:
# 9

# %%
a//b
# Out:
# 1

# %%
a1 = True
b1 = False
not(a1)
not(b1)
# Out:
# True

# %%
a1 or b1
# Out:
# True

# %%
a1 and b1
# Out:
# False
