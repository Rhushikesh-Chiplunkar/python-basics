# %%
square = [X**2 for X in range(5)]
print(square)
# Out:
# [0, 1, 4, 9, 16]
# <>:1: SyntaxWarning: invalid decimal literal
# <>:1: SyntaxWarning: invalid decimal literal
# C:\Users\chipl\AppData\Local\Temp\ipykernel_10056\846032470.py:1: SyntaxWarning: invalid decimal literal
#   square = [X**2for X in range(5)]

# %%
evens = [x for x in range(10) if x % 2 == 0]
print(evens)  # Output: [0, 2, 4, 6, 8]
# Out:
# [0, 2, 4, 6, 8]
